# %%
import torch as T
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np

# %%
class DeepQNetwork(nn.Module):
  def __init__(self, lr, input_dims, n_actions, fc1_dims, fc2_dims):
    super(DeepQNetwork, self).__init__()
    self.input_dims = input_dims
    self.fc1_dims = fc1_dims
    self.fc2_dims = fc2_dims
    self.n_actions = n_actions
    self.fc1 = nn.Linear(*self.input_dims, self.fc1_dims)
    self.fc2 = nn.Linear(self.fc1_dims, self.fc2_dims)
    self.fc3 = nn.Linear(self.fc2_dims, self.n_actions)
    self.optimizer = optim.Adam(self.parameters(), lr=lr)
    self.loss = nn.MSELoss()
    self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')
    self.to(self.device)

  def forward(self, state):
    x = F.relu(self.fc1(state))
    x = F.relu(self.fc2(x))
    actions = self.fc3(x)

    return actions

# %%
class Agent():
  def __init__(self, gamma, epsilon, lr, input_dims, batch_size, n_actions, max_mem_size=100000, eps_end=0.01, eps_dec=5e-4):
    self.gamma = gamma
    self.epsilon = epsilon
    self.eps_min = eps_end
    self.eps_dec = eps_dec
    self.lr = lr
    self.action_space=[i for i in range(n_actions)]
    self.mem_size = max_mem_size
    self.batch_size = batch_size
    self.mem_cntr = 0

    self.Q_eval = DeepQNetwork(self.lr, n_actions=n_actions, input_dims=input_dims, fc1_dims=256, fc2_dims=256)
    self.state_memory = np.zeros((self.mem_size, *input_dims), dtype=np.float32)
    self.new_state_memory = np.zeros((self.mem_size, *input_dims), dtype=np.float32)
    self.action_memory = np.zeros(self.mem_size, dtype=np.int32)
    self.reward_memory = np.zeros(self.mem_size, dtype=np.float32)
    self.terminal_memory = np.zeros(self.mem_size, dtype=np.bool)

  def convert_to_index(self, action):
    action = [str(i) for i in action]
    return int("".join(action), base=6)

  def store_transition(self, state, action, reward, state_, done):
    index = self.mem_cntr & self.mem_size
    self.state_memory[index] = state
    self.new_state_memory[index] = state_
    self.reward_memory[index] = reward
    self.action_memory[index] = self.convert_to_index(action)
    self.terminal_memory[index] = done

    self.mem_cntr += 1

  def choose_action(self, observation):
    if np.random.random() > self.epsilon:
      state = T.tensor([observation],dtype=T.float, device=self.Q_eval.device).to(self.Q_eval.device)
      actions = self.Q_eval.forward(state)
      action = T.argmax(actions).item()
    else:
      action = np.random.choice(self.action_space)
    
    digits = []
    while action > 0:
      digits.append(int(action)%6)
      action = action // 6
    digits = digits + [0]*(4-len(digits))
    return tuple(digits)

  def learn(self):
    if self.mem_cntr < self.batch_size:
      return
    
    self.Q_eval.optimizer.zero_grad()
    max_mem = min(self.mem_cntr, self.mem_size)
    batch = np.random.choice(max_mem, self.batch_size, replace=False)

    batch_index = np.arange(self.batch_size, dtype=np.int32)
    state_batch = T.tensor(self.state_memory[batch]).to(self.Q_eval.device)
    new_state_batch = T.tensor(self.new_state_memory[batch]).to(self.Q_eval.device)
    reward_batch = T.tensor(self.reward_memory[batch]).to(self.Q_eval.device)
    terminal_batch = T.tensor(self.terminal_memory[batch]).to(self.Q_eval.device)

    action_batch = self.action_memory[batch]

    q_eval = self.Q_eval.forward(state_batch)[batch_index, action_batch]
    q_next = self.Q_eval.forward(new_state_batch)
    q_next[terminal_batch] = 0.0

    q_target = reward_batch + self.gamma * T.max(q_next, dim=1)[0]
    loss = self.Q_eval.loss(q_target, q_eval).to(self.Q_eval.device)
    loss.backward()
    self.Q_eval.optimizer.step()

    self.epsilon = self.epsilon - self.eps_dec if self.epsilon > self.eps_min \
                    else self.eps_min

# %%
# This code is taken from https://github.com/jefio/gym-mastermind. This gives us the ability to use OpenAI Gym

from collections import Counter
import logging

import gym
from gym.utils import seeding
from gym import spaces


logger = logging.getLogger(__name__)


class MastermindEnv(gym.Env):
    """
    Guess a 4-digits long password where each digit is between 0 and 5.
    After each step the agent is provided with a 4-digits long tuple:
    - '2' indicates that a digit has been correclty guessed at the correct position.
    - '1' indicates that a digit has been correclty guessed but the position is wrong.
    - '0' otherwise.
    The rewards at the end of the episode are:
    0 if the agent's guess is incorrect
    1 if the agent's guess is correct
    The episode terminates after the agent guesses the target or
    12 steps have been taken.
    """
    values = 6
    size = 4
    guess_max = 12

    def __init__(self):
        self.target = None
        self.guess_count = None
        self.observation = None

        self.observation_space = spaces.Tuple(
            [spaces.Discrete(3) for _ in range(self.size)])
        self.action_space = spaces.Tuple(
            [spaces.Discrete(self.values) for _ in range(self.size)])

        self.seed()
        self.reset()

    def seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

    def get_observation(self, action):
        match_idxs = set(idx for idx, ai in enumerate(action) if ai == self.target[idx])
        n_correct = len(match_idxs)
        g_counter = Counter(self.target[idx] for idx in range(self.size) if idx not in match_idxs)
        a_counter = Counter(action[idx] for idx in range(self.size) if idx not in match_idxs)
        n_white = sum(min(g_count, a_counter[k])for k, g_count in g_counter.items())
        return tuple([0] * (self.size - n_correct - n_white) + [1] * n_white + [2] * n_correct)

    def step(self, action):
        assert self.action_space.contains(action)
        self.guess_count += 1
        done = action == self.target or self.guess_count >= self.guess_max
        match_idxs = set(idx for idx, ai in enumerate(action) if ai == self.target[idx])
        g_counter = Counter(self.target[idx] for idx in range(self.size) if idx not in match_idxs)
        a_counter = Counter(action[idx] for idx in range(self.size) if idx not in match_idxs)
        n_correct = len(match_idxs)
        n_white = sum(min(g_count, a_counter[k])for k, g_count in g_counter.items())

        reward = n_correct + 0.01*n_white - 0.2*(self.size - n_correct - n_white)

        if (action == self.target):
          reward += 10
          print("Correct")

        return self.get_observation(action), reward, done, {}

    def reset(self):
        self.target = self.action_space.sample()
        logger.debug("target=%s", self.target)
        self.guess_count = 0
        self.observation = (0,) * self.size
        return self.observation

# %%
from gym.envs.registration import register

register(
    id='Mastermind-v0',
    entry_point=MastermindEnv,
)
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/envs/registration.py:542: UserWarning: WARN: Overriding environment Mastermind-v0
#   logger.warn(f"Overriding environment {spec.id}")

# %%
env = gym.make('Mastermind-v0')
agent = Agent(gamma=0.99, epsilon=1.0, batch_size=64, n_actions=6**4-1, eps_end=0.01, input_dims=[4], lr=0.003)
scores, eps_history = [], []
n_games = 500

for i in range(n_games):
  score = 0
  done = False
  observation = env.reset()
  while not done:
    action = agent.choose_action(observation)
    observation_, reward, done, info = env.step(action)
    score += reward
    agent.store_transition(observation, action, reward, observation_, done)
    agent.learn()
    observation = observation_
  scores.append(score)
  eps_history.append(agent.epsilon)

  avg_score = np.mean(scores[-100:])

  print('Episode', i, 'score %.2f' % score, 'average score %.2f' % avg_score, 'epsilon %.2f' % agent.epsilon)
  x = [i+1 for i in range(n_games)]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# Episode 0 score 5.19 average score 5.19 epsilon 1.00
# Episode 1 score 2.46 average score 3.83 epsilon 1.00
# Episode 2 score 2.16 average score 3.27 epsilon 1.00
# Episode 3 score 1.74 average score 2.89 epsilon 1.00
# Episode 4 score 3.78 average score 3.07 epsilon 1.00
# Episode 5 score 3.30 average score 3.10 epsilon 1.00
# Episode 6 score 0.33 average score 2.71 epsilon 0.99
# Episode 7 score 3.45 average score 2.80 epsilon 0.98
# Episode 8 score 2.52 average score 2.77 epsilon 0.98
# Episode 9 score 1.53 average score 2.65 epsilon 0.97
# Episode 10 score -0.09 average score 2.40 epsilon 0.97
# Episode 11 score -2.85 average score 1.96 epsilon 0.96
# Episode 12 score 3.93 average score 2.11 epsilon 0.95
# Episode 13 score 7.68 average score 2.51 epsilon 0.95
# Episode 14 score 7.11 average score 2.82 epsilon 0.94
# Episode 15 score 4.41 average score 2.92 epsilon 0.94
# Episode 16 score 3.36 average score 2.94 epsilon 0.93
# Episode 17 score 0.48 average score 2.80 epsilon 0.92
# Episode 18 score -1.29 average score 2.59 epsilon 0.92
# Episode 19 score 5.40 average score 2.73 epsilon 0.91
# Episode 20 score 1.44 average score 2.67 epsilon 0.91
# Episode 21 score 0.60 average score 2.57 epsilon 0.90
# Episode 22 score 3.09 average score 2.60 epsilon 0.89
# Episode 23 score 4.44 average score 2.67 epsilon 0.89
# Episode 24 score 5.40 average score 2.78 epsilon 0.88
# Episode 25 score 2.52 average score 2.77 epsilon 0.88
# Episode 26 score 0.33 average score 2.68 epsilon 0.87
# Episode 27 score 4.14 average score 2.73 epsilon 0.86
# Episode 28 score 0.60 average score 2.66 epsilon 0.86
# Episode 29 score 2.31 average score 2.65 epsilon 0.85
# Episode 30 score 2.94 average score 2.66 epsilon 0.85
# Episode 31 score 13.53 average score 3.00 epsilon 0.84
# Episode 32 score 3.15 average score 3.00 epsilon 0.83
# Episode 33 score -5.10 average score 2.76 epsilon 0.83
# Episode 34 score 1.74 average score 2.74 epsilon 0.82
# Episode 35 score 3.93 average score 2.77 epsilon 0.82
# Episode 36 score 3.87 average score 2.80 epsilon 0.81
# Episode 37 score -5.37 average score 2.58 epsilon 0.80
# Episode 38 score 0.18 average score 2.52 epsilon 0.80
# Episode 39 score 6.69 average score 2.63 epsilon 0.79
# Episode 40 score 7.62 average score 2.75 epsilon 0.79
# Episode 41 score -3.90 average score 2.59 epsilon 0.78
# Episode 42 score 0.18 average score 2.53 epsilon 0.77
# Episode 43 score 5.01 average score 2.59 epsilon 0.77
# Episode 44 score -0.51 average score 2.52 epsilon 0.76
# Episode 45 score 1.38 average score 2.50 epsilon 0.76
# Episode 46 score 5.13 average score 2.55 epsilon 0.75
# Episode 47 score 0.96 average score 2.52 epsilon 0.74
# Episode 48 score 0.39 average score 2.48 epsilon 0.74
# Episode 49 score -1.35 average score 2.40 epsilon 0.73
# Episode 50 score 6.48 average score 2.48 epsilon 0.73
# Episode 51 score 1.95 average score 2.47 epsilon 0.72
# Episode 52 score -5.16 average score 2.32 epsilon 0.71
# Episode 53 score 1.59 average score 2.31 epsilon 0.71
# Episode 54 score -4.53 average score 2.19 epsilon 0.70
# Episode 55 score 3.93 average score 2.22 epsilon 0.70
# Episode 56 score 4.77 average score 2.26 epsilon 0.69
# Episode 57 score 3.57 average score 2.29 epsilon 0.68
# Episode 58 score 0.45 average score 2.25 epsilon 0.68
# Episode 59 score 2.88 average score 2.26 epsilon 0.67
# Episode 60 score 8.67 average score 2.37 epsilon 0.67
# Episode 61 score 12.48 average score 2.53 epsilon 0.66
# Episode 62 score 2.10 average score 2.53 epsilon 0.65
# Episode 63 score 2.16 average score 2.52 epsilon 0.65
# Episode 64 score 3.72 average score 2.54 epsilon 0.64
# Episode 65 score -4.11 average score 2.44 epsilon 0.64
# Episode 66 score 3.87 average score 2.46 epsilon 0.63
# Episode 67 score -0.57 average score 2.41 epsilon 0.62
# Episode 68 score 1.74 average score 2.40 epsilon 0.62
# Episode 69 score 4.14 average score 2.43 epsilon 0.61
# Episode 70 score 5.85 average score 2.48 epsilon 0.61
# Episode 71 score 11.91 average score 2.61 epsilon 0.60
# Episode 72 score 8.52 average score 2.69 epsilon 0.59
# Episode 73 score -1.50 average score 2.63 epsilon 0.59
# Episode 74 score 6.27 average score 2.68 epsilon 0.58
# Episode 75 score 2.58 average score 2.68 epsilon 0.58
# Episode 76 score -0.75 average score 2.64 epsilon 0.57
# Episode 77 score -4.17 average score 2.55 epsilon 0.56
# Episode 78 score -0.87 average score 2.51 epsilon 0.56
# Episode 79 score 8.43 average score 2.58 epsilon 0.55
# Episode 80 score 0.90 average score 2.56 epsilon 0.55
# Episode 81 score 3.51 average score 2.57 epsilon 0.54
# Episode 82 score 0.84 average score 2.55 epsilon 0.53
# Episode 83 score -2.13 average score 2.49 epsilon 0.53
# Episode 84 score 5.28 average score 2.53 epsilon 0.52
# Episode 85 score 7.74 average score 2.59 epsilon 0.52
# Episode 86 score 1.26 average score 2.57 epsilon 0.51
# Episode 87 score 1.53 average score 2.56 epsilon 0.50
# Episode 88 score 9.45 average score 2.64 epsilon 0.50
# Episode 89 score -0.87 average score 2.60 epsilon 0.49
# Episode 90 score -3.39 average score 2.53 epsilon 0.49
# Episode 91 score 6.12 average score 2.57 epsilon 0.48
# Episode 92 score 16.56 average score 2.72 epsilon 0.47
# Episode 93 score 0.75 average score 2.70 epsilon 0.47
# Episode 94 score 2.88 average score 2.70 epsilon 0.46
# Episode 95 score -3.69 average score 2.64 epsilon 0.46
# Episode 96 score 10.29 average score 2.72 epsilon 0.45
# Episode 97 score 4.71 average score 2.74 epsilon 0.44
# Episode 98 score 4.71 average score 2.76 epsilon 0.44
# Episode 99 score 6.27 average score 2.79 epsilon 0.43
# Episode 100 score 1.53 average score 2.75 epsilon 0.43
# Episode 101 score 10.23 average score 2.83 epsilon 0.42
# Episode 102 score 2.67 average score 2.84 epsilon 0.41
# Episode 103 score -3.33 average score 2.79 epsilon 0.41
# Episode 104 score -0.81 average score 2.74 epsilon 0.40
# Episode 105 score 9.09 average score 2.80 epsilon 0.40
# Episode 106 score -4.11 average score 2.75 epsilon 0.39
# Correct
# Episode 107 score 16.84 average score 2.89 epsilon 0.39
# Episode 108 score 6.12 average score 2.92 epsilon 0.38
# Episode 109 score 10.44 average score 3.01 epsilon 0.38
# Episode 110 score 4.14 average score 3.06 epsilon 0.37
# Episode 111 score 6.96 average score 3.15 epsilon 0.36
# Episode 112 score -4.26 average score 3.07 epsilon 0.36
# Episode 113 score 9.93 average score 3.09 epsilon 0.35
# Episode 114 score 2.94 average score 3.05 epsilon 0.35
# Episode 115 score -2.34 average score 2.98 epsilon 0.34
# Episode 116 score 0.48 average score 2.96 epsilon 0.33
# Episode 117 score 6.48 average score 3.02 epsilon 0.33
# Episode 118 score -5.31 average score 2.98 epsilon 0.32
# Episode 119 score 4.71 average score 2.97 epsilon 0.32
# Episode 120 score 0.24 average score 2.96 epsilon 0.31
# Episode 121 score -4.41 average score 2.91 epsilon 0.30
# Episode 122 score -7.77 average score 2.80 epsilon 0.30
# Episode 123 score 6.96 average score 2.82 epsilon 0.29
# Episode 124 score 3.78 average score 2.81 epsilon 0.29
# Episode 125 score -0.51 average score 2.78 epsilon 0.28
# Episode 126 score -2.91 average score 2.74 epsilon 0.27
# Episode 127 score 4.29 average score 2.75 epsilon 0.27
# Episode 128 score 2.52 average score 2.76 epsilon 0.26
# Episode 129 score 6.48 average score 2.81 epsilon 0.26
# Episode 130 score 30.21 average score 3.08 epsilon 0.25
# Episode 131 score 9.63 average score 3.04 epsilon 0.24
# Episode 132 score -7.98 average score 2.93 epsilon 0.24
# Episode 133 score 6.75 average score 3.05 epsilon 0.23
# Episode 134 score 4.50 average score 3.08 epsilon 0.23
# Episode 135 score -4.68 average score 2.99 epsilon 0.22
# Episode 136 score -1.50 average score 2.94 epsilon 0.21
# Episode 137 score -5.37 average score 2.94 epsilon 0.21
# Episode 138 score 2.52 average score 2.96 epsilon 0.20
# Episode 139 score 15.30 average score 3.04 epsilon 0.20
# Episode 140 score 1.38 average score 2.98 epsilon 0.19
# Episode 141 score -5.16 average score 2.97 epsilon 0.18
# Episode 142 score -2.07 average score 2.95 epsilon 0.18
# Episode 143 score 9.30 average score 2.99 epsilon 0.17
# Episode 144 score -9.60 average score 2.90 epsilon 0.17
# Episode 145 score -7.35 average score 2.81 epsilon 0.16
# Episode 146 score 15.51 average score 2.92 epsilon 0.15
# Episode 147 score 13.05 average score 3.04 epsilon 0.15
# Episode 148 score 4.71 average score 3.08 epsilon 0.14
# Episode 149 score -9.60 average score 3.00 epsilon 0.14
# Episode 150 score 11.64 average score 3.05 epsilon 0.13
# Episode 151 score -6.03 average score 2.97 epsilon 0.12
# Episode 152 score -2.85 average score 2.99 epsilon 0.12
# Episode 153 score -1.56 average score 2.96 epsilon 0.11
# Episode 154 score 5.91 average score 3.07 epsilon 0.11
# Episode 155 score -3.75 average score 2.99 epsilon 0.10
# Episode 156 score 1.95 average score 2.96 epsilon 0.09
# Episode 157 score -9.60 average score 2.83 epsilon 0.09
# Episode 158 score -3.78 average score 2.79 epsilon 0.08
# Episode 159 score -7.71 average score 2.68 epsilon 0.08
# Episode 160 score -3.78 average score 2.56 epsilon 0.07
# Episode 161 score 4.80 average score 2.48 epsilon 0.06
# Episode 162 score 0.03 average score 2.46 epsilon 0.06
# Episode 163 score 3.24 average score 2.47 epsilon 0.05
# Episode 164 score -9.60 average score 2.34 epsilon 0.05
# Episode 165 score -9.60 average score 2.28 epsilon 0.04
# Episode 166 score 1.74 average score 2.26 epsilon 0.03
# Episode 167 score -9.60 average score 2.17 epsilon 0.03
# Episode 168 score -9.60 average score 2.06 epsilon 0.02
# Episode 169 score 19.41 average score 2.21 epsilon 0.02
# Episode 170 score 0.12 average score 2.15 epsilon 0.01
# Episode 171 score 6.12 average score 2.09 epsilon 0.01
# Episode 172 score -9.60 average score 1.91 epsilon 0.01
# Episode 173 score -9.60 average score 1.83 epsilon 0.01
# Episode 174 score -6.09 average score 1.71 epsilon 0.01
# Episode 175 score 0.12 average score 1.68 epsilon 0.01
# Episode 176 score -9.60 average score 1.59 epsilon 0.01
# Episode 177 score -9.60 average score 1.54 epsilon 0.01
# Episode 178 score -9.60 average score 1.45 epsilon 0.01
# Episode 179 score -9.60 average score 1.27 epsilon 0.01
# Episode 180 score 4.41 average score 1.31 epsilon 0.01
# Episode 181 score 11.19 average score 1.38 epsilon 0.01
# Episode 182 score -9.60 average score 1.28 epsilon 0.01
# Episode 183 score -9.60 average score 1.21 epsilon 0.01
# Episode 184 score -9.60 average score 1.06 epsilon 0.01
# Episode 185 score -9.60 average score 0.88 epsilon 0.01
# Episode 186 score -9.60 average score 0.77 epsilon 0.01
# Episode 187 score -1.68 average score 0.74 epsilon 0.01
# Episode 188 score 3.27 average score 0.68 epsilon 0.01
# Episode 189 score 4.80 average score 0.74 epsilon 0.01
# Episode 190 score -9.60 average score 0.68 epsilon 0.01
# Episode 191 score 6.69 average score 0.68 epsilon 0.01
# Episode 192 score -9.60 average score 0.42 epsilon 0.01
# Episode 193 score 28.23 average score 0.69 epsilon 0.01
# Episode 194 score 7.20 average score 0.74 epsilon 0.01
# Episode 195 score 4.50 average score 0.82 epsilon 0.01
# Episode 196 score 4.86 average score 0.77 epsilon 0.01
# Episode 197 score -9.60 average score 0.62 epsilon 0.01
# Episode 198 score 11.49 average score 0.69 epsilon 0.01
# Episode 199 score -9.60 average score 0.53 epsilon 0.01
# Episode 200 score 0.12 average score 0.52 epsilon 0.01
# Episode 201 score 1.59 average score 0.43 epsilon 0.01
# Episode 202 score -9.60 average score 0.31 epsilon 0.01
# Episode 203 score -4.17 average score 0.30 epsilon 0.01
# Episode 204 score -9.60 average score 0.21 epsilon 0.01
# Episode 205 score -9.60 average score 0.02 epsilon 0.01
# Episode 206 score -9.60 average score -0.03 epsilon 0.01
# Episode 207 score -9.60 average score -0.29 epsilon 0.01
# Episode 208 score 10.41 average score -0.25 epsilon 0.01
# Episode 209 score -3.78 average score -0.39 epsilon 0.01
# Episode 210 score 7.32 average score -0.36 epsilon 0.01
# Episode 211 score -9.18 average score -0.52 epsilon 0.01
# Episode 212 score -9.60 average score -0.58 epsilon 0.01
# Episode 213 score -9.60 average score -0.77 epsilon 0.01
# Episode 214 score 7.11 average score -0.73 epsilon 0.01
# Episode 215 score 16.35 average score -0.54 epsilon 0.01
# Episode 216 score -1.44 average score -0.56 epsilon 0.01
# Episode 217 score -9.60 average score -0.72 epsilon 0.01
# Episode 218 score -9.60 average score -0.77 epsilon 0.01
# Episode 219 score 1.20 average score -0.80 epsilon 0.01
# Episode 220 score 1.83 average score -0.79 epsilon 0.01
# Episode 221 score -9.60 average score -0.84 epsilon 0.01
# Episode 222 score -9.60 average score -0.86 epsilon 0.01
# Episode 223 score -7.20 average score -1.00 epsilon 0.01
# Episode 224 score -9.60 average score -1.13 epsilon 0.01
# Episode 225 score -9.60 average score -1.22 epsilon 0.01
# Episode 226 score 6.48 average score -1.13 epsilon 0.01
# Episode 227 score -9.60 average score -1.27 epsilon 0.01
# Episode 228 score -9.60 average score -1.39 epsilon 0.01
# Episode 229 score 11.28 average score -1.34 epsilon 0.01
# Episode 230 score 13.26 average score -1.51 epsilon 0.01
# Episode 231 score -9.60 average score -1.70 epsilon 0.01
# Episode 232 score -9.60 average score -1.72 epsilon 0.01
# Episode 233 score -9.60 average score -1.88 epsilon 0.01
# Episode 234 score -9.60 average score -2.02 epsilon 0.01
# Episode 235 score -9.18 average score -2.07 epsilon 0.01
# Episode 236 score -9.60 average score -2.15 epsilon 0.01
# Episode 237 score 4.80 average score -2.05 epsilon 0.01
# Episode 238 score 12.00 average score -1.95 epsilon 0.01
# Episode 239 score -9.60 average score -2.20 epsilon 0.01
# Episode 240 score -8.76 average score -2.30 epsilon 0.01
# Episode 241 score 11.07 average score -2.14 epsilon 0.01
# Episode 242 score 4.29 average score -2.08 epsilon 0.01
# Episode 243 score 7.11 average score -2.10 epsilon 0.01
# Episode 244 score 17.01 average score -1.83 epsilon 0.01
# Episode 245 score -1.14 average score -1.77 epsilon 0.01
# Episode 246 score 6.06 average score -1.87 epsilon 0.01
# Episode 247 score -0.87 average score -2.00 epsilon 0.01
# Episode 248 score 19.20 average score -1.86 epsilon 0.01
# Episode 249 score 13.26 average score -1.63 epsilon 0.01
# Episode 250 score 19.20 average score -1.56 epsilon 0.01
# Episode 251 score -9.60 average score -1.59 epsilon 0.01
# Episode 252 score 0.12 average score -1.56 epsilon 0.01
# Episode 253 score -9.60 average score -1.64 epsilon 0.01
# Episode 254 score 0.12 average score -1.70 epsilon 0.01
# Episode 255 score -9.60 average score -1.76 epsilon 0.01
# Episode 256 score 1.38 average score -1.76 epsilon 0.01
# Episode 257 score 11.73 average score -1.55 epsilon 0.01
# Episode 258 score 4.14 average score -1.47 epsilon 0.01
# Episode 259 score 0.12 average score -1.39 epsilon 0.01
# Episode 260 score 1.38 average score -1.34 epsilon 0.01
# Episode 261 score -9.60 average score -1.49 epsilon 0.01
# Episode 262 score -9.60 average score -1.58 epsilon 0.01
# Episode 263 score -9.60 average score -1.71 epsilon 0.01
# Episode 264 score 19.20 average score -1.42 epsilon 0.01
# Episode 265 score 19.20 average score -1.13 epsilon 0.01
# Episode 266 score 19.20 average score -0.96 epsilon 0.01
# Episode 267 score -9.60 average score -0.96 epsilon 0.01
# Episode 268 score -9.60 average score -0.96 epsilon 0.01
# Episode 269 score 6.69 average score -1.09 epsilon 0.01
# Episode 270 score -9.60 average score -1.18 epsilon 0.01
# Episode 271 score 6.06 average score -1.18 epsilon 0.01
# Episode 272 score 9.66 average score -0.99 epsilon 0.01
# Episode 273 score -9.60 average score -0.99 epsilon 0.01
# Episode 274 score 19.20 average score -0.74 epsilon 0.01
# Episode 275 score 5.91 average score -0.68 epsilon 0.01
# Episode 276 score -9.60 average score -0.68 epsilon 0.01
# Episode 277 score 0.12 average score -0.58 epsilon 0.01
# Episode 278 score 1.38 average score -0.47 epsilon 0.01
# Episode 279 score -9.60 average score -0.47 epsilon 0.01
# Episode 280 score 4.86 average score -0.47 epsilon 0.01
# Episode 281 score -9.18 average score -0.67 epsilon 0.01
# Episode 282 score 7.32 average score -0.50 epsilon 0.01
# Episode 283 score 0.12 average score -0.41 epsilon 0.01
# Episode 284 score -9.60 average score -0.41 epsilon 0.01
# Episode 285 score 19.20 average score -0.12 epsilon 0.01
# Episode 286 score -9.60 average score -0.12 epsilon 0.01
# Episode 287 score -9.60 average score -0.20 epsilon 0.01
# Episode 288 score 19.20 average score -0.04 epsilon 0.01
# Episode 289 score -9.60 average score -0.18 epsilon 0.01
# Episode 290 score 3.93 average score -0.05 epsilon 0.01
# Episode 291 score -9.60 average score -0.21 epsilon 0.01
# Episode 292 score 1.38 average score -0.10 epsilon 0.01
# Episode 293 score -0.09 average score -0.38 epsilon 0.01
# Episode 294 score 1.38 average score -0.44 epsilon 0.01
# Episode 295 score 1.38 average score -0.47 epsilon 0.01
# Episode 296 score 4.20 average score -0.48 epsilon 0.01
# Episode 297 score 19.20 average score -0.19 epsilon 0.01
# Episode 298 score 19.20 average score -0.11 epsilon 0.01
# Episode 299 score 0.12 average score -0.02 epsilon 0.01
# Episode 300 score -9.60 average score -0.11 epsilon 0.01
# Episode 301 score 19.20 average score 0.06 epsilon 0.01
# Episode 302 score 0.12 average score 0.16 epsilon 0.01
# Episode 303 score 5.01 average score 0.25 epsilon 0.01
# Episode 304 score 0.75 average score 0.35 epsilon 0.01
# Episode 305 score -9.60 average score 0.35 epsilon 0.01
# Episode 306 score 18.90 average score 0.64 epsilon 0.01
# Episode 307 score 1.38 average score 0.75 epsilon 0.01
# Episode 308 score 9.24 average score 0.74 epsilon 0.01
# Episode 309 score -9.60 average score 0.68 epsilon 0.01
# Episode 310 score -1.14 average score 0.59 epsilon 0.01
# Episode 311 score -9.60 average score 0.59 epsilon 0.01
# Episode 312 score -9.60 average score 0.59 epsilon 0.01
# Episode 313 score 1.26 average score 0.70 epsilon 0.01
# Episode 314 score -6.78 average score 0.56 epsilon 0.01
# Episode 315 score 8.01 average score 0.48 epsilon 0.01
# Episode 316 score 7.11 average score 0.56 epsilon 0.01
# Episode 317 score 19.20 average score 0.85 epsilon 0.01
# Episode 318 score 19.20 average score 1.14 epsilon 0.01
# Episode 319 score 4.80 average score 1.17 epsilon 0.01
# Episode 320 score 0.84 average score 1.16 epsilon 0.01
# Episode 321 score 7.11 average score 1.33 epsilon 0.01
# Episode 322 score -9.60 average score 1.33 epsilon 0.01
# Episode 323 score 7.11 average score 1.47 epsilon 0.01
# Episode 324 score -0.30 average score 1.57 epsilon 0.01
# Episode 325 score 3.15 average score 1.69 epsilon 0.01
# Episode 326 score 0.12 average score 1.63 epsilon 0.01
# Episode 327 score 1.38 average score 1.74 epsilon 0.01
# Episode 328 score -1.14 average score 1.83 epsilon 0.01
# Episode 329 score -9.60 average score 1.62 epsilon 0.01
# Episode 330 score 0.12 average score 1.49 epsilon 0.01
# Episode 331 score 0.12 average score 1.58 epsilon 0.01
# Episode 332 score 14.52 average score 1.82 epsilon 0.01
# Episode 333 score -9.18 average score 1.83 epsilon 0.01
# Episode 334 score 6.63 average score 1.99 epsilon 0.01
# Episode 335 score -9.60 average score 1.99 epsilon 0.01
# Episode 336 score -9.60 average score 1.99 epsilon 0.01
# Episode 337 score -9.60 average score 1.84 epsilon 0.01
# Episode 338 score -9.60 average score 1.63 epsilon 0.01
# Episode 339 score 10.86 average score 1.83 epsilon 0.01
# Episode 340 score 0.12 average score 1.92 epsilon 0.01
# Episode 341 score 19.20 average score 2.00 epsilon 0.01
# Episode 342 score 3.51 average score 1.99 epsilon 0.01
# Episode 343 score 9.42 average score 2.02 epsilon 0.01
# Episode 344 score 19.20 average score 2.04 epsilon 0.01
# Episode 345 score -9.60 average score 1.95 epsilon 0.01
# Episode 346 score 19.20 average score 2.08 epsilon 0.01
# Episode 347 score 3.03 average score 2.12 epsilon 0.01
# Episode 348 score 19.20 average score 2.12 epsilon 0.01
# Episode 349 score 4.80 average score 2.04 epsilon 0.01
# Episode 350 score -9.60 average score 1.75 epsilon 0.01
# Episode 351 score 19.20 average score 2.04 epsilon 0.01
# Episode 352 score -9.60 average score 1.94 epsilon 0.01
# Episode 353 score 33.60 average score 2.37 epsilon 0.01
# Episode 354 score -9.60 average score 2.28 epsilon 0.01
# Episode 355 score -9.60 average score 2.28 epsilon 0.01
# Episode 356 score 3.24 average score 2.30 epsilon 0.01
# Episode 357 score -1.14 average score 2.17 epsilon 0.01
# Episode 358 score 9.42 average score 2.22 epsilon 0.01
# Episode 359 score -9.60 average score 2.12 epsilon 0.01
# Episode 360 score -9.60 average score 2.01 epsilon 0.01
# Episode 361 score -9.60 average score 2.01 epsilon 0.01
# Episode 362 score -9.60 average score 2.01 epsilon 0.01
# Episode 363 score -9.60 average score 2.01 epsilon 0.01
# Episode 364 score -9.60 average score 1.72 epsilon 0.01
# Episode 365 score -9.60 average score 1.44 epsilon 0.01
# Episode 366 score -9.60 average score 1.15 epsilon 0.01
# Episode 367 score -9.60 average score 1.15 epsilon 0.01
# Episode 368 score -1.35 average score 1.23 epsilon 0.01
# Episode 369 score 4.20 average score 1.21 epsilon 0.01
# Episode 370 score -9.60 average score 1.21 epsilon 0.01
# Episode 371 score 7.11 average score 1.22 epsilon 0.01
# Episode 372 score -9.60 average score 1.02 epsilon 0.01
# Episode 373 score 1.32 average score 1.13 epsilon 0.01
# Episode 374 score -0.09 average score 0.94 epsilon 0.01
# Episode 375 score -9.60 average score 0.79 epsilon 0.01
# Episode 376 score -9.60 average score 0.79 epsilon 0.01
# Episode 377 score -0.72 average score 0.78 epsilon 0.01
# Episode 378 score -9.60 average score 0.67 epsilon 0.01
# Episode 379 score 3.93 average score 0.80 epsilon 0.01
# Episode 380 score 6.69 average score 0.82 epsilon 0.01
# Episode 381 score 19.20 average score 1.10 epsilon 0.01
# Episode 382 score 19.20 average score 1.22 epsilon 0.01
# Episode 383 score -9.60 average score 1.13 epsilon 0.01
# Episode 384 score -9.60 average score 1.13 epsilon 0.01
# Episode 385 score 9.63 average score 1.03 epsilon 0.01
# Episode 386 score 3.60 average score 1.16 epsilon 0.01
# Episode 387 score 0.12 average score 1.26 epsilon 0.01
# Episode 388 score 0.12 average score 1.07 epsilon 0.01
# Episode 389 score 4.80 average score 1.21 epsilon 0.01
# Episode 390 score 19.20 average score 1.37 epsilon 0.01
# Episode 391 score -9.60 average score 1.37 epsilon 0.01
# Episode 392 score -9.60 average score 1.26 epsilon 0.01
# Episode 393 score 18.21 average score 1.44 epsilon 0.01
# Episode 394 score -9.60 average score 1.33 epsilon 0.01
# Episode 395 score 1.20 average score 1.33 epsilon 0.01
# Episode 396 score 4.80 average score 1.33 epsilon 0.01
# Episode 397 score -9.60 average score 1.04 epsilon 0.01
# Episode 398 score 4.80 average score 0.90 epsilon 0.01
# Episode 399 score 19.20 average score 1.09 epsilon 0.01
# Episode 400 score -9.60 average score 1.09 epsilon 0.01
# Episode 401 score -9.60 average score 0.80 epsilon 0.01
# Episode 402 score -9.60 average score 0.71 epsilon 0.01
# Episode 403 score -9.60 average score 0.56 epsilon 0.01
# Episode 404 score -1.14 average score 0.54 epsilon 0.01
# Episode 405 score 6.84 average score 0.71 epsilon 0.01
# Episode 406 score -9.60 average score 0.42 epsilon 0.01
# Episode 407 score 2.67 average score 0.43 epsilon 0.01
# Episode 408 score -9.60 average score 0.25 epsilon 0.01
# Episode 409 score -9.60 average score 0.25 epsilon 0.01
# Episode 410 score -8.19 average score 0.17 epsilon 0.01
# Episode 411 score -9.60 average score 0.17 epsilon 0.01
# Episode 412 score -9.60 average score 0.17 epsilon 0.01
# Episode 413 score -9.60 average score 0.07 epsilon 0.01
# Episode 414 score 2.52 average score 0.16 epsilon 0.01
# Episode 415 score -9.60 average score -0.02 epsilon 0.01
# Episode 416 score 19.20 average score 0.10 epsilon 0.01
# Episode 417 score 33.60 average score 0.25 epsilon 0.01
# Episode 418 score -9.60 average score -0.04 epsilon 0.01
# Episode 419 score -9.60 average score -0.18 epsilon 0.01
# Episode 420 score -9.60 average score -0.29 epsilon 0.01
# Episode 421 score 19.20 average score -0.17 epsilon 0.01
# Episode 422 score -9.60 average score -0.17 epsilon 0.01
# Episode 423 score -9.60 average score -0.33 epsilon 0.01
# Episode 424 score 33.60 average score 0.00 epsilon 0.01
# Episode 425 score 9.00 average score 0.06 epsilon 0.01
# Episode 426 score 8.31 average score 0.14 epsilon 0.01
# Episode 427 score -9.60 average score 0.04 epsilon 0.01
# Episode 428 score -9.60 average score -0.05 epsilon 0.01
# Episode 429 score -9.60 average score -0.05 epsilon 0.01
# Episode 430 score -9.60 average score -0.15 epsilon 0.01
# Episode 431 score -9.60 average score -0.24 epsilon 0.01
# Episode 432 score 10.65 average score -0.28 epsilon 0.01
# Episode 433 score -9.60 average score -0.29 epsilon 0.01
# Episode 434 score 19.20 average score -0.16 epsilon 0.01
# Episode 435 score 1.32 average score -0.05 epsilon 0.01
# Episode 436 score 17.91 average score 0.22 epsilon 0.01
# Episode 437 score -1.14 average score 0.31 epsilon 0.01
# Episode 438 score 9.42 average score 0.50 epsilon 0.01
# Episode 439 score 7.11 average score 0.46 epsilon 0.01
# Episode 440 score 7.11 average score 0.53 epsilon 0.01
# Episode 441 score 1.17 average score 0.35 epsilon 0.01
# Episode 442 score -9.60 average score 0.22 epsilon 0.01
# Episode 443 score -9.60 average score 0.03 epsilon 0.01
# Episode 444 score -9.60 average score -0.26 epsilon 0.01
# Episode 445 score 6.27 average score -0.10 epsilon 0.01
# Episode 446 score -9.60 average score -0.39 epsilon 0.01
# Episode 447 score -9.60 average score -0.51 epsilon 0.01
# Episode 448 score -9.60 average score -0.80 epsilon 0.01
# Episode 449 score -9.60 average score -0.95 epsilon 0.01
# Episode 450 score 12.00 average score -0.73 epsilon 0.01
# Episode 451 score -9.60 average score -1.02 epsilon 0.01
# Episode 452 score 4.65 average score -0.88 epsilon 0.01
# Episode 453 score 19.20 average score -1.02 epsilon 0.01
# Episode 454 score -9.60 average score -1.02 epsilon 0.01
# Episode 455 score -9.60 average score -1.02 epsilon 0.01
# Episode 456 score -9.60 average score -1.15 epsilon 0.01
# Episode 457 score 0.12 average score -1.14 epsilon 0.01
# Episode 458 score -9.60 average score -1.33 epsilon 0.01
# Episode 459 score -9.60 average score -1.33 epsilon 0.01
# Episode 460 score -9.60 average score -1.33 epsilon 0.01
# Episode 461 score -9.60 average score -1.33 epsilon 0.01
# Episode 462 score -1.14 average score -1.24 epsilon 0.01
# Episode 463 score -9.60 average score -1.24 epsilon 0.01
# Episode 464 score -9.60 average score -1.24 epsilon 0.01
# Episode 465 score 4.80 average score -1.10 epsilon 0.01
# Episode 466 score -9.60 average score -1.10 epsilon 0.01
# Episode 467 score -9.60 average score -1.10 epsilon 0.01
# Episode 468 score 4.80 average score -1.04 epsilon 0.01
# Episode 469 score -9.60 average score -1.17 epsilon 0.01
# Episode 470 score -9.60 average score -1.17 epsilon 0.01
# Episode 471 score -9.60 average score -1.34 epsilon 0.01
# Episode 472 score 14.52 average score -1.10 epsilon 0.01
# Episode 473 score -9.60 average score -1.21 epsilon 0.01
# Episode 474 score -5.79 average score -1.27 epsilon 0.01
# Episode 475 score -9.60 average score -1.27 epsilon 0.01
# Episode 476 score 4.80 average score -1.12 epsilon 0.01
# Episode 477 score 19.20 average score -0.92 epsilon 0.01
# Episode 478 score 19.20 average score -0.64 epsilon 0.01
# Episode 479 score -9.60 average score -0.77 epsilon 0.01
# Episode 480 score 3.81 average score -0.80 epsilon 0.01
# Episode 481 score -9.60 average score -1.09 epsilon 0.01
# Episode 482 score -9.39 average score -1.37 epsilon 0.01
# Episode 483 score 19.20 average score -1.09 epsilon 0.01
# Episode 484 score -9.60 average score -1.09 epsilon 0.01
# Episode 485 score -9.60 average score -1.28 epsilon 0.01
# Episode 486 score 5.22 average score -1.26 epsilon 0.01
# Episode 487 score 19.20 average score -1.07 epsilon 0.01
# Episode 488 score -9.60 average score -1.17 epsilon 0.01
# Episode 489 score 4.80 average score -1.17 epsilon 0.01
# Episode 490 score -9.60 average score -1.46 epsilon 0.01
# Episode 491 score 5.01 average score -1.31 epsilon 0.01
# Episode 492 score -9.60 average score -1.31 epsilon 0.01
# Episode 493 score -9.60 average score -1.59 epsilon 0.01
# Episode 494 score -9.60 average score -1.59 epsilon 0.01
# Episode 495 score 19.20 average score -1.41 epsilon 0.01
# Episode 496 score 4.80 average score -1.41 epsilon 0.01
# Episode 497 score 4.80 average score -1.26 epsilon 0.01
# Episode 498 score -9.60 average score -1.41 epsilon 0.01
# Episode 499 score -9.60 average score -1.70 epsilon 0.01
